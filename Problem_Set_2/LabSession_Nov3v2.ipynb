# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <div id="toc"></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# # Import dependencies and load data

# %%
import pandas as pd
import numpy as np
import sys
import operator
from scipy import stats
import requests
from IPython.display import HTML
import matplotlib.pylab as plt
import warnings
import geopandas as gpd
from fiona.crs import from_epsg

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# These are the "Tableau 20" colors as RGB.
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]
 
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.
for i in range(len(tableau20)):
    r, g, b = tableau20[i]
    tableau20[i] = (r / 255., g / 255., b / 255.)

plt.rcParams['figure.figsize'] = 12, 8
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['font.serif'] = 'Arial'
plt.rcParams['font.family'] = "sans-serif"
plt.rcParams['axes.titlesize'] = 22
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.rcParams['figure.frameon'] = False
plt.rcParams['axes.prop_cycle'] = cycler('color',tableau20)
plt.rcParams['legend.frameon'] = False
plt.rcParams['legend.fontsize'] = 14

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Read data
df_xls = pd.read_excel(r'http://www.nyc.gov/html/gbee/downloads/excel/nyc_benchmarking_disclosure_data_reported_in_2016.xlsx')

# Convert to .csv
df_xls.to_csv(r'..\data\nyc_benchmarking_disclosure_data_reported_in_2016.csv', encoding='utf-8')
df = pd.read_csv(r'..\data\nyc_benchmarking_disclosure_data_reported_in_2016.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Record Number  Order  NYC Borough, Block and Lot (BBL)  \
# 0           0      4113711.0      1                      1.003360e+09
# 1           1      4630135.0      2                      1.010618e+09
# 2           2      4626594.0      3                      1.014270e+09
# 3           3      4626608.0      4                      1.015180e+09
# 4           4      5048763.0      5                      1.003920e+09
#
#   Co-reported BBL Status BBLs Co-reported  \
# 0                    NaN              NaN
# 1                    NaN              NaN
# 2                    NaN              NaN
# 3                    NaN              NaN
# 4                    NaN              NaN
#
#   Reported NYC Building Identification Numbers (BINs)  \
# 0                                            1088884
# 1                                            1026728
# 2                                            1043974
# 3                                            1048117
# 4                                            1079685
#
#                                Property Name  \
# 0                       16 Bialystoker Place
# 1  (7478) - 432 West 52nd Street Condominium
# 2              (9250) - 250 East 73rd Street
# 3              (9141) - 141 East 89th Street
# 4                            605 East 9th ST
#
#                     Parent Property Id                 Parent Property Name  \
# 0  Not Applicable: Standalone Property  Not Applicable: Standalone Property
# 1  Not Applicable: Standalone Property  Not Applicable: Standalone Property
# 2  Not Applicable: Standalone Property  Not Applicable: Standalone Property
# 3  Not Applicable: Standalone Property  Not Applicable: Standalone Property
# 4  Not Applicable: Standalone Property  Not Applicable: Standalone Property
#
#    Street Number           Street Name  Zip Code    Borough  \
# 0           15.0  BIALYSTOKER PLACE      10002.0  Manhattan
# 1          432.0  WEST   52 STREET       10019.0  Manhattan
# 2         1393.0     2 AVENUE            10021.0  Manhattan
# 3         1341.0  LEXINGTON AVENUE       10128.0  Manhattan
# 4          350.0  EAST   10 STREET       10009.0  Manhattan
#
#   DOF Benchmarking Submission Status Primary Property Type - Self Selected  \
# 0                      In Compliance                   Multifamily Housing
# 1                      In Compliance                   Multifamily Housing
# 2                      In Compliance                   Multifamily Housing
# 3                      In Compliance                   Multifamily Housing
# 4                      In Compliance              Residence Hall/Dormitory
#
#   List of All Property Use Types at Property Largest Property Use Type  \
# 0                        Multifamily Housing       Multifamily Housing
# 1                        Multifamily Housing       Multifamily Housing
# 2                        Multifamily Housing       Multifamily Housing
# 3                        Multifamily Housing       Multifamily Housing
# 4                   Residence Hall/Dormitory             Not Available
#
#    Largest Property Use Type - Gross Floor Area (ft²)  \
# 0                                            98000.0
# 1                                            57401.0
# 2                                           166433.0
# 3                                           114939.0
# 4                                                NaN
#
#   2nd Largest Property Use Type  \
# 0                 Not Available
# 1                 Not Available
# 2                 Not Available
# 3                 Not Available
# 4                 Not Available
#
#   2nd Largest Property Use - Gross Floor Area (ft²)  \
# 0                                     Not Available
# 1                                     Not Available
# 2                                     Not Available
# 3                                     Not Available
# 4                                     Not Available
#
#   3rd Largest Property Use Type  \
# 0                 Not Available
# 1                 Not Available
# 2                 Not Available
# 3                 Not Available
# 4                 Not Available
#
#   3rd Largest Property Use Type - Gross Floor Area (ft²) Year Built  \
# 0                                      Not Available           1982
# 1                                      Not Available           1950
# 2                                      Not Available           1964
# 3                                      Not Available           1960
# 4                                      Not Available           2018
#
#    Number of Buildings - Self-reported  Occupancy Metered Areas (Energy)  \
# 0                                  1.0      100.0         Whole Building
# 1                                  1.0       95.0         Whole Building
# 2                                  1.0       95.0         Whole Building
# 3                                  1.0       95.0         Whole Building
# 4                                  1.0        0.0          Not Available
#
#   Metered Areas  (Water)  ENERGY STAR Score  Site EUI (kBtu/ft²)  \
# 0          Not Available               87.0                 73.7
# 1         Whole Building               79.0                 51.3
# 2         Whole Building               80.0                 44.9
# 3         Whole Building               10.0                 91.3
# 4          Not Available                NaN                  NaN
#
#    Weather Normalized Site EUI (kBtu/ft²)  \
# 0                                    74.4
# 1                                    50.9
# 2                                    44.5
# 3                                    90.8
# 4                                     NaN
#
#    Weather Normalized Site Electricity Intensity (kWh/ft²)  \
# 0                                                5.3
# 1                                                7.5
# 2                                                8.2
# 3                                               12.0
# 4                                                NaN
#
#    Weather Normalized Site Natural Gas Intensity (therms/ft²)  \
# 0                                                0.6
# 1                                                0.3
# 2                                                0.2
# 3                                                0.5
# 4                                                NaN
#
#    Source EUI (kBtu/ft²)  Weather Normalized Source EUI (kBtu/ft²)  \
# 0                  115.0                                     115.7
# 1                  108.8                                     107.1
# 2                  106.7                                     105.2
# 3                  182.4                                     180.7
# 4                    NaN                                       NaN
#
#   Fuel Oil #1 Use (kBtu) Fuel Oil #2 Use (kBtu) Fuel Oil #4 Use (kBtu)  \
# 0          Not Available          Not Available          Not Available
# 1          Not Available          Not Available          Not Available
# 2          Not Available          Not Available          Not Available
# 3          Not Available          Not Available          Not Available
# 4          Not Available          Not Available          Not Available
#
#   Fuel Oil #5 & 6 Use (kBtu) Diesel #2 Use (kBtu) District Steam Use (kBtu)  \
# 0              Not Available        Not Available             Not Available
# 1              Not Available        Not Available             Not Available
# 2              Not Available        Not Available             Not Available
# 3              Not Available        Not Available             Not Available
# 4              Not Available        Not Available             Not Available
#
#   District Hot Water Use (kBtu) District Chilled Water Use (kBtu)  \
# 0                 Not Available                     Not Available
# 1                 Not Available                     Not Available
# 2                 Not Available                     Not Available
# 3                 Not Available                     Not Available
# 4                 Not Available                     Not Available
#
#    Natural Gas Use (kBtu)  Weather Normalized Site Natural Gas Use (therms)  \
# 0               5463399.1                                           55261.4
# 1               1437732.8                                           14515.6
# 2               2739020.0                                           27390.2
# 3               5733933.4                                           57339.3
# 4                     NaN                                               NaN
#
#    Electricity Use - Grid Purchase (kBtu)  \
# 0                               1762214.1
# 1                               1507302.8
# 2                               4737201.3
# 3                               4759700.8
# 4                                     NaN
#
#    Weather Normalized Site Electricity (kWh)  \
# 0                                   516475.3
# 1                                   431480.2
# 2                                  1365852.0
# 3                                  1377116.1
# 4                                        NaN
#
#    Total GHG Emissions (Metric Tons CO2e)  \
# 0                                   436.3
# 1                                   201.4
# 2                                   538.4
# 3                                   699.3
# 4                                     0.0
#
#    Direct GHG Emissions (Metric Tons CO2e)  \
# 0                                    290.2
# 1                                     76.4
# 2                                    145.5
# 3                                    304.6
# 4                                      0.0
#
#    Indirect GHG Emissions (Metric Tons CO2e)  DOF Property Floor Area (ft²)  \
# 0                                      146.1                        98052.0
# 1                                      125.0                        58851.0
# 2                                      392.9                       166432.0
# 3                                      394.7                       114939.0
# 4                                        0.0                        93420.0
#
#    Property GFA - Self-reported (ft²)  Water Use (All Water Sources) (kgal)  \
# 0                             98000.0                                   NaN
# 1                             57401.0                                 768.5
# 2                            166433.0                               11901.5
# 3                            114939.0                                7455.1
# 4                            111000.0                                   NaN
#
#    Municipally Supplied Potable Water - Indoor Intensity (gal/ft²)  \
# 0                                                NaN
# 1                                              13.39
# 2                                              71.51
# 3                                              64.86
# 4                                                NaN
#
#           Release Date  DEP Provided Water Use (kgal)  \
# 0  2016-04-13 11:08:48                            NaN
# 1  2016-04-26 21:52:05                            NaN
# 2  2016-04-26 22:56:36                        11897.0
# 3  2016-04-26 22:38:03                         7455.1
# 4  2016-07-28 17:28:14                            NaN
#
#   Automatic Water Benchmarking Eligible Reported Water Method
# 0                                   NaN                   NaN
# 1                          Not Eligible                   NaN
# 2                              Eligible                Manual
# 3                              Eligible                   ABS
# 4                                   NaN                   NaN

# %%
del df['Unnamed: 0']

# This transformation is in case your system doesn't recognize the current encoding
cols = df.columns.str.replace('\xc2\xb2', '_2')
df.columns = cols

# %%
df.columns
# Out:
# Index([u'Record Number', u'Order', u'NYC Borough, Block and Lot (BBL)',
#        u'Co-reported BBL Status', u'BBLs Co-reported',
#        u'Reported NYC Building Identification Numbers (BINs)',
#        u'Property Name', u'Parent Property Id', u'Parent Property Name',
#        u'Street Number', u'Street Name', u'Zip Code', u'Borough',
#        u'DOF Benchmarking Submission Status',
#        u'Primary Property Type - Self Selected',
#        u'List of All Property Use Types at Property',
#        u'Largest Property Use Type',
#        u'Largest Property Use Type - Gross Floor Area (ft_2)',
#        u'2nd Largest Property Use Type',
#        u'2nd Largest Property Use - Gross Floor Area (ft_2)',
#        u'3rd Largest Property Use Type',
#        u'3rd Largest Property Use Type - Gross Floor Area (ft_2)',
#        u'Year Built', u'Number of Buildings - Self-reported', u'Occupancy',
#        u'Metered Areas (Energy)', u'Metered Areas  (Water)',
#        u'ENERGY STAR Score', u'Site EUI (kBtu/ft_2)',
#        u'Weather Normalized Site EUI (kBtu/ft_2)',
#        u'Weather Normalized Site Electricity Intensity (kWh/ft_2)',
#        u'Weather Normalized Site Natural Gas Intensity (therms/ft_2)',
#        u'Source EUI (kBtu/ft_2)', u'Weather Normalized Source EUI (kBtu/ft_2)',
#        u'Fuel Oil #1 Use (kBtu)', u'Fuel Oil #2 Use (kBtu)',
#        u'Fuel Oil #4 Use (kBtu)', u'Fuel Oil #5 & 6 Use (kBtu)',
#        u'Diesel #2 Use (kBtu)', u'District Steam Use (kBtu)',
#        u'District Hot Water Use (kBtu)', u'District Chilled Water Use (kBtu)',
#        u'Natural Gas Use (kBtu)',
#        u'Weather Normalized Site Natural Gas Use (therms)',
#        u'Electricity Use - Grid Purchase (kBtu)',
#        u'Weather Normalized Site Electricity (kWh)',
#        u'Total GHG Emissions (Metric Tons CO2e)',
#        u'Direct GHG Emissions (Metric Tons CO2e)',
#        u'Indirect GHG Emissions (Metric Tons CO2e)',
#        u'DOF Property Floor Area (ft_2)',
#        u'Property GFA - Self-reported (ft_2)',
#        u'Water Use (All Water Sources) (kgal)',
#        u'Municipally Supplied Potable Water - Indoor Intensity (gal/ft_2)',
#        u'Release Date', u'DEP Provided Water Use (kgal)',
#        u'Automatic Water Benchmarking Eligible', u'Reported Water Method'],
#       dtype='object')

# %% [markdown]
# # Data inspection

# %% [markdown]
# ### Question: Show the top 5 mostly encountered building typologies

# %%
mydict = dict(zip(df.groupby('Primary Property Type - Self Selected')['Order'].count().index, 
         df.groupby('Primary Property Type - Self Selected')['Order'].count().values))

# show top 5 mostly encountered building typologies
sorted(mydict.items(), key=operator.itemgetter(1), reverse=True)[:6]
# Out:
# [('Multifamily Housing', 8699),
#  ('Office', 1233),
#  ('See Primary BBL', 447),
#  ('Hotel', 236),
#  ('Non-Refrigerated Warehouse', 177),
#  ('Other', 129)]

# %%
df = df[df['Primary Property Type - Self Selected'] == 'Multifamily Housing']

# %%
df.describe()
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        Record Number         Order  NYC Borough, Block and Lot (BBL)  \
# count   8.699000e+03   8699.000000                      8.698000e+03
# mean    3.476663e+06   6351.661800                      2.225283e+09
# std     8.229126e+05   3267.420728                      1.181873e+09
# min     1.443214e+06      1.000000                      1.000088e+09
# 25%     2.742914e+06   3765.000000                               NaN
# 50%     3.114529e+06   6373.000000                               NaN
# 75%     4.384553e+06   9181.500000                               NaN
# max     5.053345e+06  11971.000000                      5.054918e+09
#
#        Street Number      Zip Code  \
# count    6978.000000   8487.000000
# mean     1108.404271  10610.728879
# std      1694.046711    568.795592
# min         1.000000  10001.000000
# 25%              NaN           NaN
# 50%              NaN           NaN
# 75%              NaN           NaN
# max     76179.000000  11694.000000
#
#        Largest Property Use Type - Gross Floor Area (ft_2)  \
# count                                       8.699000e+03
# mean                                        1.467861e+05
# std                                         2.299528e+05
# min                                         5.800000e+01
# 25%                                         6.510000e+04
# 50%                                         8.821400e+04
# 75%                                         1.452840e+05
# max                                         6.940450e+06
#
#        Number of Buildings - Self-reported    Occupancy  ENERGY STAR Score  \
# count                          8699.000000  8699.000000        7513.000000
# mean                              1.490746    99.616623          56.629842
# std                               4.153277     3.358280          30.477155
# min                               0.000000     0.000000           1.000000
# 25%                               1.000000   100.000000                NaN
# 50%                               1.000000   100.000000                NaN
# 75%                               1.000000   100.000000                NaN
# max                             161.000000   100.000000         100.000000
#
#        Site EUI (kBtu/ft_2)  Weather Normalized Site EUI (kBtu/ft_2)  \
# count           8654.000000                              7440.000000
# mean             405.938456                               448.661250
# std             9520.852245                             10224.456799
# min                0.000000                                 0.000000
# 25%                     NaN                                      NaN
# 50%                     NaN                                      NaN
# 75%                     NaN                                      NaN
# max           801504.700000                            798135.700000
#
#        Weather Normalized Site Electricity Intensity (kWh/ft_2)  \
# count                                        8406.000000
# mean                                           13.919153
# std                                           228.398920
# min                                             0.000000
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         10510.900000
#
#        Weather Normalized Site Natural Gas Intensity (therms/ft_2)  \
# count                                        7458.000000
# mean                                            2.238898
# std                                            95.844071
# min                                             0.000000
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                          7981.000000
#
#        Source EUI (kBtu/ft_2)  Weather Normalized Source EUI (kBtu/ft_2)  \
# count             8654.000000                                7440.000000
# mean               548.974451                                 592.683306
# std              10564.343498                               11268.237888
# min                  0.000000                                   0.100000
# 25%                       NaN                                        NaN
# 50%                       NaN                                        NaN
# 75%                       NaN                                        NaN
# max             841652.400000                              838112.300000
#
#        Natural Gas Use (kBtu)  \
# count            7.914000e+03
# mean             2.991518e+07
# std              1.347821e+09
# min              0.000000e+00
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max              1.101676e+11
#
#        Weather Normalized Site Natural Gas Use (therms)  \
# count                                      7.458000e+03
# mean                                       3.078148e+05
# std                                        1.387439e+07
# min                                        0.000000e+00
# 25%                                                 NaN
# 50%                                                 NaN
# 75%                                                 NaN
# max                                        1.101676e+09
#
#        Electricity Use - Grid Purchase (kBtu)  \
# count                            8.643000e+03
# mean                             4.536019e+06
# std                              5.199372e+07
# min                              0.000000e+00
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                              3.729784e+09
#
#        Weather Normalized Site Electricity (kWh)  \
# count                               8.406000e+03
# mean                                1.280868e+06
# std                                 1.493466e+07
# min                                 0.000000e+00
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                 1.093137e+09
#
#        Total GHG Emissions (Metric Tons CO2e)  \
# count                            8.669000e+03
# mean                             4.093800e+03
# std                              8.535570e+04
# min                              0.000000e+00
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                              5.860677e+06
#
#        Direct GHG Emissions (Metric Tons CO2e)  \
# count                             8.669000e+03
# mean                              1.628570e+03
# std                               6.841710e+04
# min                               0.000000e+00
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                               5.852949e+06
#
#        Indirect GHG Emissions (Metric Tons CO2e)  \
# count                               8.679000e+03
# mean                                2.462726e+03
# std                                 5.095997e+04
# min                                 0.000000e+00
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                 2.193799e+06
#
#        DOF Property Floor Area (ft_2)  Property GFA - Self-reported (ft_2)  \
# count                    8.487000e+03                         8.699000e+03
# mean                     1.405344e+05                         1.499596e+05
# std                      2.599077e+05                         2.329603e+05
# min                      5.002800e+04                         5.800000e+01
# 25%                               NaN                         6.620950e+04
# 50%                               NaN                         8.958000e+04
# 75%                               NaN                         1.480205e+05
# max                      8.512479e+06                         6.940450e+06
#
#        Water Use (All Water Sources) (kgal)  \
# count                          5.499000e+03
# mean                           1.193724e+04
# std                            8.786550e+04
# min                            0.000000e+00
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                            3.638813e+06
#
#        Municipally Supplied Potable Water - Indoor Intensity (gal/ft_2)  \
# count                                        4956.000000
# mean                                           94.932849
# std                                           860.237215
# min                                             0.000000
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         52143.200000
#
#        DEP Provided Water Use (kgal)
# count                    4560.000000
# mean                     6801.782149
# std                      7047.573041
# min                         1.000000
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                    129781.600000

# %%
# Check if there are missing values
print "Are there missing values? -->", df['Site EUI (kBtu/ft_2)'].isnull().values.any()
print "There are %i missing values out of %i properties (%.1f percent)" %(df['Site EUI (kBtu/ft_2)'].isnull().sum(), 
                                                                        len(df), 
                                                                        df['Site EUI (kBtu/ft_2)'].isnull().sum()
                                                                          /float(len(df))*100)
# Out:
# Are there missing values? --> True
# There are 45 missing values out of 8699 properties (0.5 percent)

# %% [markdown]
# # Data cleaning

# %%
# Drop nans
df = df.dropna(subset=['Site EUI (kBtu/ft_2)'])
print 'Examples after dropping NaNs:', len(df)
# Out:
# Examples after dropping NaNs: 8654

# %%
# Drop zero EUI values
df = df[df['Site EUI (kBtu/ft_2)']>0]
print 'Examples after dropping zeros:', len(df)
# Out:
# Examples after dropping zeros: 8652

# %%
#plt.hist(df['Site EUI (kBtu/ft_2)'], bins=200)
plt.hist(df['Site EUI (kBtu/ft_2)'][df['Site EUI (kBtu/ft_2)']<1000], bins=200)
plt.show()

# %% [markdown]
# __Idea:__ Transform data to approximate the normal distribution --> Select cutoff thresholds based on standard deviations --> Return clean data
#
# ![title](../material/transformEUI.png)

# %% [markdown]
# ### Question: Transform EUI and remove examples falling outside 2 std from the mean

# %%
def clean(df):
    """Takes the logarithm of EUI for a particular building type and filters out
    examples that fall outside the threshold of two standard deviations.
    
    Returns outlier-free dataframe."""
    
    df = df[(df.log_eui<np.mean(df.log_eui)+2*np.std(df.log_eui))&(df.log_eui>np.mean(df.log_eui)-2*np.std(df.log_eui))]
    return df

df['eui'] = df['Site EUI (kBtu/ft_2)']
df['log_eui'] = np.log10(df.eui)
df = clean(df)
print 'Examples after cleaning EUI:', len(df)
# Out:
# Examples after cleaning EUI: 8369

# %%
df.eui.describe()
# Out:
# count    8369.000000
# mean       87.188804
# std        29.988660
# min        21.000000
# 25%        69.200000
# 50%        83.400000
# 75%       101.300000
# max       304.800000
# Name: eui, dtype: float64

# %%
plt.hist(df['Site EUI (kBtu/ft_2)'], bins=200)
for label, pos in zip(['A', 'B', 'C'], df['Site EUI (kBtu/ft_2)'].describe()[4:7].values):
    plt.axvline(x=pos, color='firebrick', linestyle='--')
    plt.text(pos-10, 220, label, fontsize=15)
plt.text(pos+10, 220, 'D', fontsize=15)
plt.title('Site EUI distribution (Multifamily housing)')
plt.xlabel('Site EUI ($kbtu/ft^{2}$)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Understanding relationships

# %%
def makeCorrPlots(x, y):
    
    """Takes two variables as inputs, fits a univariate linear regression model,
    and outputs the scatter plot, linear fit and correlation coefficient"""
    
    # drop nans
    tmp = df[[x,y]]
    tmp = tmp.dropna()
    
    # fit univariate regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(tmp[x].astype(float), tmp[y])
    
    # plot2
    plt.scatter(tmp[x].astype(float), tmp[y], color=tableau20[0], alpha=0.5)
    plt.plot(tmp[x].astype(float),intercept + slope*tmp[x].astype('float'), color='firebrick')
    plt.title('%s v. %s (corr= %.2f)' %(y, x, np.corrcoef(tmp[x].astype('float'), tmp[y])[0][1]))

# %%
plt.figure(figsize=(20,20))
for i, var in enumerate(['Year Built', 'Property GFA - Self-reported (ft_2)', 'Occupancy', 'ENERGY STAR Score'],1):
    plt.subplot(2,2,i)
    makeCorrPlots(var, 'eui')

# %% [markdown]
# __Statistical Modeling__
#
#
#
# * __Linear v. Non-linear__
#
#
#
# * __Predicted efficiency v. Actual efficiency__
